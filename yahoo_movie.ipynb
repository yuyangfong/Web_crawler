# %%
import requests
import re
import json
from bs4 import BeautifulSoup


Y_MOVIE_URL = 'https://tw.movies.yahoo.com/movie_thisweek.html'

# 以下網址後面加上 "/id=MOVIE_ID" 即為該影片各項資訊
Y_INTRO_URL = 'https://tw.movies.yahoo.com/movieinfo_main.html'     # 詳細資訊
Y_PHOTO_URL = 'https://tw.movies.yahoo.com/movieinfo_photos.html'   # 劇照
Y_TIME_URL = 'https://tw.movies.yahoo.com/movietime_result.html'    # 時刻表


def get_web_page(url):
    resp = requests.get(url)
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text


def get_movies(dom):
    soup = BeautifulSoup(dom, 'html5lib')
    movies = []
    rows = soup.find_all('div', 'release_info_text')
    for row in rows:
        movie = dict()
        movie['expectation'] = row.find('div', 'leveltext').span.text.strip()
        movie['ch_name'] = row.find('div', 'release_movie_name').a.text.strip()
        movie['eng_name'] = row.find('div', 'release_movie_name').find('div', 'en').a.text.strip()
        movie['movie_id'] = get_movie_id(row.find('div', 'release_movie_name').a['href'])
        movie['poster_url'] = row.parent.find_previous_sibling('div', 'release_foto').a.img['src']
        movie['release_date'] = get_date(row.find('div', 'release_movie_time').text)
        movie['intro'] = row.find('div', 'release_text').text.replace(u'詳全文', '').strip()
        trailer_a = row.find_next_sibling('div', 'release_btn color_btnbox').find_all('a')[1]
        movie['trailer_url'] = trailer_a['href'] if 'href' in trailer_a.attrs.keys() else ''
        movies.append(movie)
    return movies


def get_date(date_str):
    # e.g. "上映日期：2017-03-23" -> match.group(0): "2017-03-23"
    pattern = '\d+-\d+-\d+'
    match = re.search(pattern, date_str)
    if match is None:
        return date_str
    else:
        return match.group(0)


def get_movie_id(url):
    # 1. https://movies.yahoo.com.tw/movie_thisweek.html
    # 2. https://movies.yahoo.com.tw/movieinfo_main.html/id=6981
    #      -> match.group(0): "/id=6707"
    pattern = '/id=\d+'
    match = re.search(pattern, url)
    if match is None:
        return url
    else:
        return match.group(0).replace('/id=', '')


def get_trailer_url(url):
    # e.g., 'https://tw.rd.yahoo.com/referurl/movie/thisweek/trailer/*https://tw.movies.yahoo.com/video/美女與野獸-最終版預告-024340912.html'
    return url.split('*')[1]


def main():
    page = get_web_page(Y_MOVIE_URL)
    if page:
        movies = get_movies(page)
        for movie in movies:
            print(movie)
        with open('movie.json', 'w', encoding='utf-8') as f:
            json.dump(movies, f, indent=2, sort_keys=True, ensure_ascii=False)


if __name__ == '__main__':
    main()
# Out:
# {'expectation': '71%', 'ch_name': '星際叛將：歐西里斯之子', 'eng_name': 'The Osiris Child: Science Fiction Volume One', 'movie_id': '6985', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/December2017/zZtBpEFeIK4DdPP2yhfl-1984x2834.JPG', 'release_date': '2018-01-05', 'intro': "★《星際異攻隊2》《鋼鐵英雄》特效團隊，打造全新科幻史詩鉅作！\n\xa0\n★當《星際特工瓦雷諾：千星之城》強碰《越獄風雲》，激戰異星球！\n\xa0\n★“愛死這部片了！動作場面超屌、演技出色、特效更驚人” - Ain't It C...", 'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%98%9F%E9%9A%9B%E5%8F%9B%E5%B0%87-%E6%AD%90%E8%A5%BF%E9%87%8C%E6%96%AF%E4%B9%8B%E5%AD%90-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-130404298.html?movie_id=6985'}
# {'expectation': '89%', 'ch_name': '最黑暗的時刻', 'eng_name': 'Darkest Hour', 'movie_id': '7015', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/December2017/A3q6bEXTwBI4zgcffBzo-5942x8800.JPG', 'release_date': '2018-01-05', 'intro': '一個讓人振奮和啟發的真實故事在第二次世界大戰前夕展開，在溫斯頓邱吉爾（奧斯卡金獎提名蓋瑞歐德曼 飾）成為英國首相之後的幾天內，就必須面對他最具爭議與挑戰性的考驗：該與德國納粹談判和平協定，亦或是堅守一個國家的立國理念，...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%9C%80%E9%BB%91%E6%9A%97%E7%9A%84%E6%99%82%E5%88%BB-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-071131093.html?movie_id=7015'}
# {'expectation': '90%', 'ch_name': '陰兒房第4章：鎖命亡靈', 'eng_name': 'Insidious: Chapter 4', 'movie_id': '7212', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/September2017/L32SZXRv9r6cNw8v0K5a-1957x2793.jpg', 'release_date': '2018-01-05', 'intro': '繼《陰兒房》系列前作皆創下亮眼的票房佳績後，最新作品《陰兒房第4章：鎖命亡靈》劇本由《陰兒房》系列原創團隊之一的雷沃納爾執筆，並由華裔名導溫子仁監製、《失魂記憶》導演亞當羅勃提爾執導。全新電影更找來《分裂》及《逃出絕命...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E9%99%B0%E5%85%92%E6%88%BF%E7%AC%AC4%E7%AB%A0-%E9%8E%96%E5%91%BD%E4%BA%A1%E9%9D%88-%E5%89%8D%E5%B0%8E%E9%A0%90%E5%91%8A-055941926.html?movie_id=7212'}
# {'expectation': '93%', 'ch_name': '逆境棋蹟', 'eng_name': 'The Cheess Player', 'movie_id': '7350', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/October2017/8IiFbNe9fyf1w4zVgfRk-1887x2691.jpg', 'release_date': '2018-01-05', 'intro': '★改編西班牙暢銷同名小說！\n★好來塢國際配樂大師幕後操刀！\n★磅礡哥德式風格重現二次大戰納粹風！！\n★逆境重生 過目不忘再現天才西洋棋手！！\n★挑戰各路好手人生再現逆轉棋步！！！\n\xa0\n本片改自西班牙暢銷同名小說！\n1934...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E9%80%86%E5%A2%83%E6%A3%8B%E8%B9%9F-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-042139522.html?movie_id=7350'}
# {'expectation': '81%', 'ch_name': 'JOJO的奇妙冒險：不滅鑽石', 'eng_name': 'Jojo’s Bizarre Adventure: Diamond is Unbreakable', 'movie_id': '7488', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2017/IeeYjuHUMnO2CCwtoBi1-4299x6083.jpg', 'release_date': '2018-01-05', 'intro': '★榮獲瑞士納沙泰爾國際奇幻電影節\u3000競賽單元-最受觀眾喜愛獎\xa0\n★榮獲維也納科幻與恐怖電影節\u3000指定放映\n★加拿大奇幻電影節放映、錫切斯影展、里茲國際影展\u3000指定放映\n★入圍 南特科幻烏托邦展 國際競賽單元\n★全球熱賣突破一億...', 'trailer_url': 'https://movies.yahoo.com.tw/video/jojo%E7%9A%84%E5%A5%87%E5%A6%99%E5%86%92%E9%9A%AA-%E4%B8%8D%E6%BB%85%E9%91%BD%E7%9F%B3-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-130534589.html?movie_id=7488'}
# {'expectation': '85%', 'ch_name': '幸福路上', 'eng_name': 'On Happiness Road', 'movie_id': '7504', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2017/dUV7xD4KzFemu0MYb20l-1500x2143.png', 'release_date': '2018-01-05', 'intro': '小時候，我們都希望成為閃亮亮的大人\n長大後，卻只想要平凡的幸福\n\xa0\n小琪6歲時跟著爸媽一起搬到台北，懵懂無知的小琪不懂什麼叫做幸福，卻十分期待在「幸福路」的新生活。上學後的小琪，努力成為一個好學生，希望自己可以出人...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E5%B9%B8%E7%A6%8F%E8%B7%AF%E4%B8%8A-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-060407029.html?movie_id=7504'}
# {'expectation': '81%', 'ch_name': '親愛的外人', 'eng_name': 'Dear Etranger', 'movie_id': '7507', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2017/XarxIRiClFeDkLQQPWD4-1772x2526.jpg', 'release_date': '2018-01-05', 'intro': '★ 2017日本報知電影獎最佳導演、最佳女配角\n★ 2017蒙特婁國際影展評審團特別獎\n★ 直木獎暢銷作家 重松清 原著小說改編\n\xa0\n跟我同住的女兒們，不是我親生的\xa0 我親生的女兒，現在是別人的女兒\n信（淺野忠信 飾）歷經一場...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E8%A6%AA%E6%84%9B%E7%9A%84%E5%A4%96%E4%BA%BA-%E7%8D%A8%E5%AE%B6%E5%95%8F%E5%80%99%E7%AF%87-120736407.html?movie_id=7507'}
# {'expectation': '75%', 'ch_name': '維京傳說：寒冰交鋒', 'eng_name': 'Viking', 'movie_id': '7525', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/November2017/3wpTcUolSzxr27y45BpZ-1984x2835.JPG', 'release_date': '2018-01-05', 'intro': '★ 史實改編，斯拉夫傳說寶典《原初編年史》結合冰島《王者傳說》之史詩鉅作\n★《GQ》雜誌盛讚視覺設計宏偉壯麗，外媒譽為「俄羅斯版《冰與火之歌：權力遊戲》」！\xa0\n★ 刷新影史票房紀錄，9天突破15.6億盧布，勇奪年度俄羅斯電影...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E7%B6%AD%E4%BA%AC%E5%82%B3%E8%AA%AA-%E5%AF%92%E5%86%B0%E4%BA%A4%E9%8B%92-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-110938547.html?movie_id=7525'}
# {'expectation': '90%', 'ch_name': '我要活下去', 'eng_name': '6 Below: Miracle on the Mountain', 'movie_id': '7574', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/December2017/zwV0gcIGmQGKEGBP2MNX-840x1200.jpg', 'release_date': '2018-01-05', 'intro': '★ 繼《127小時》後，又一撼動人心的「奇蹟生還」真人真事改編！\n★ 冰天雪地，糧盡援絕，前奧運選手必須在死亡邊緣挑戰生存極限！\n★ 美國《綜藝》雜誌狂推：「十大必看導演」！\n★ 美國《時人雜誌》盛讚：「史上最棒的生存電影之一」...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E6%88%91%E8%A6%81%E6%B4%BB%E4%B8%8B%E5%8E%BB-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-030937898.html?movie_id=7574'}
# {'expectation': '89%', 'ch_name': '老獸', 'eng_name': 'Old Beast', 'movie_id': '7586', 'poster_url': 'https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/December2017/oYWkQTdRHMZPEsRA936z-1800x2547.jpg', 'release_date': '2018-01-05', 'intro': '★榮獲2017年金馬獎最佳男主角、最佳原著劇本、費比西國際影評人獎3項大獎肯定\n★故事犀利、影像大膽，直砭社會問題，天然渾成，生猛凌厲\n★一個混蛋老爸，被自己的子女綁架，是家庭悲劇也是時代產物\n\xa0\n老楊（涂們 飾）已經60多...', 'trailer_url': 'https://movies.yahoo.com.tw/video/%E8%80%81%E7%8D%B8-%E8%A7%A3%E8%AE%80%E7%89%88%E9%A0%90%E5%91%8A-073241380.html?movie_id=7586'}
